# %% [markdown]
# # Tugas Minggu ke-1
# Nama  : Daffa Asyqar Ahmad Khalisheka
#
# NIM   : 1103200034

# %% [markdown]
# # Hello, Python 🐍

# %% [markdown]
# # 💻 Exercise: Syntax, Variables, and Numbers 💻

# %% [markdown]
# 0. *What is your favorite color? *
#
# To complete this question, create a variable called color in the cell below with an appropriate value. The function call q0.check() (which we've already provided in the cell below) will check your answer.

# %%
# Question 0

# create a variable called color with an appropriate value on the line below
# (Remember, strings in Python must be enclosed in 'single' or "double" quotes)

color = "blue"  # #Mengassign string "biru" ke variabel color

# Menampilkan nilai variabel color
print(color)
# Out:
# blue

# %% [markdown]
# 1. Complete the code below. In case it's helpful, here is the table of available arithmetic operations:
#
# ![Screenshot 2023-09-29 045404.png](data:image/png;base64,...)

# %%
# Question 1

pi = 3.14159  # perkiraan
diameter = 3

# Membuat variabel 'radius' yang sama dengan setengah dari diameter
radius = diameter / 2

# Membuat variabel 'area', menggunakan rumus untuk luas lingkaran: pi dikali radius pangkat 2
area = pi * (radius ** 2)

# Menampilkan hasil perhitungan
print("Nilai pi:", pi)
print("Diameter lingkaran:", diameter)
print("Radius lingkaran:", radius)
print("Luas lingkaran:", area)
# Out:
# Nilai pi: 3.14159
# Diameter lingkaran: 3
# Radius lingkaran: 1.5
# Luas lingkaran: 7.0685775

# %% [markdown]
# 2. Add code to the following cell to swap variables `a` and `b` (so that `a` refers to the object previously referred to by `b` and vice versa).

# %%
########### Setup code - don't touch this part ######################
# If you're curious, these are examples of lists. We'll talk about
# them in depth a few lessons from now. For now, just know that they're
# yet another type of Python object, like int or float.
a = [1, 2, 3]
b = [3, 2, 1]
######################################################################

# Simpan nilai awal variabel a ke dalam variabel sementara
temp = a

# Assign nilai variabel b ke variabel a
a = b

# Assign nilai variabel sementara (yang berisi nilai awal a) ke variabel b
b = temp

# Menampilkan Hasilnya
print("Variabel a setelah pertukaran:", a)
print("Variabel b setelah pertukaran:", b)
# Out:
# Variabel a setelah pertukaran: [3, 2, 1]
# Variabel b setelah pertukaran: [1, 2, 3]

# %% [markdown]
# 3a. Add parentheses to the following expression so that it evaluates to 1.

# %%
#5 - 3 // 2

(5 - 3) // 2
# Out:
# 1

# %% [markdown]
# 3b. 🌶️
#
# Questions, like this one, marked a spicy pepper are a bit harder.</small>
#
# Add parentheses to the following expression so that it evaluates to 0.

# %%
#8 - 3 * 2 - 1 + 1

(8 - 3) * (2 - (1 + 1))
# Out:
# 0

# %% [markdown]
# 4. Alice, Bob and Carol have agreed to pool their Halloween candy and split it evenly among themselves. For the sake of their friendship, any candies left over will be smashed. For example, if they collectively bring home 91 candies, they'll take 30 each and smash 1.
#
# Write an arithmetic expression below to calculate how many candies they must smash for a given haul.

# %%
# Variables representing the number of candies collected by alice, bob, and carol
alice_candies = 121
bob_candies = 77
carol_candies = 109

# Your code goes here! Replace the right-hand side of this assignment with an expression
# involving alice_candies, bob_candies, and carol_candies

# Menghitung jumlah permen yang harus dihancurkan
to_smash = (alice_candies + bob_candies + carol_candies) % 3

# Menampilkan jumlah permen yang harus dihancurkan
print("Jumlah permen yang harus dihancurkan:", to_smash)
# Out:
# Jumlah permen yang harus dihancurkan: 1

# %% [markdown]
# # 💻 Exercise: Functions and Getting Help 💻

# %% [markdown]
# 1. Complete the body of the following function according to its docstring.
#
# HINT: Python has a built-in function `round`.

# %%
def round_to_two_places(num):
    """Mengembalikan angka yang diberikan dibulatkan menjadi dua tempat desimal.

    >>> round_to_two_places(3.14159)
    3.14
    """
    return round(num, 2)

# Menggunakan fungsi dengan contoh angka
angka = 3.14159
hasil_bulat = round_to_two_places(angka)

# Menampilkan hasilnya
print("Angka setelah dibulatkan:", hasil_bulat)
# Out:
# Angka setelah dibulatkan: 3.14

# %% [markdown]
# 2. The help for `round` says that `ndigits` (the second argument) may be negative.
# What do you think will happen when it is? Try some examples in the following cell.

# %%
number = 1234.56789

# Menggunakan round dengan ndigits negatif
rounded = round(number, -2)

# Menampilkan hasilnya
print(rounded)
# Out:
# 1200.0

# %% [markdown]
# 3. In the previous exercise, the candy-sharing friends Alice, Bob and Carol tried to split candies evenly. For the sake of their friendship, any candies left over would be smashed. For example, if they collectively bring home 91 candies, they'll take 30 each and smash 1.
#
# Below is a simple function that will calculate the number of candies to smash for any number of total candies.
#
# Modify it so that it optionally takes a second argument representing the number of friends the candies are being split between. If no second argument is provided, it should assume 3 friends, as before.
#
# Update the docstring to reflect this new behaviour.

# %%
def to_smash(total_candies, num_friends=3):
    """Return the number of leftover candies that must be smashed after distributing
    the given number of candies evenly between the specified number of friends.

    >>> to_smash(91)
    1
    """
    return total_candies % num_friends

# Memanggil fungsi to_smash dengan total_candies=91 (menggunakan nilai default num_friends=3)
result = to_smash(91)
print(f"Jumlah permen: 91, Sisa permen yang harus dihancurkan: {result}")
# Out:
# Jumlah permen: 91, Sisa permen yang harus dihancurkan: 1

# %% [markdown]
# 4. (Optional)
#
# It may not be fun, but reading and understanding error messages will be an important part of your Python career.
#
# Each code cell below contains some commented buggy code. For each cell...
#
# Read the code and predict what you think will happen when it's run.
# Then uncomment the code and run it to see what happens. (Tip: In the kernel editor, you can highlight several lines and press ctrl+/ to toggle commenting.)
# Fix the code (so that it accomplishes its intended purpose without throwing an exception)

# %%
# ruound_to_two_places(9.9999)

# Menggunakan fungsi round untuk membulatkan 9.9999 menjadi 2 desimal
result = round(9.9999, 2)
# Mencetak hasilnya
print(result)
# Out:
# 10.0

# %%
# x = -10
# y = 5
# # Which of the two variables above has the smallest absolute value?
# smallest_abs = min(abs(x, y))

# Mendefinisikan dua variabel x dan y
x = -10
y = 5

# Mencari nilai absolut terkecil antara x dan y
smallest_abs = min(abs(x), abs(y))

# Mencetak nilai absolut terkecil
print(smallest_abs)
# Out:
# 5

# %%
# def f(x):
#     y = abs(x)
# return y

# print(f(5))

# Mendefinisikan fungsi f(x) yang mengembalikan nilai absolut dari x
def f(x):
    y = abs(x)
    return y

# Memanggil fungsi f dengan argumen 5
print(f(5))
# Out:
# 5

# %% [markdown]
# ## 💻 Exercise: Booleans and Conditionals 💻

# %% [markdown]
# 1. Many programming languages have sign available as a built-in function. Python doesn't, but we can define our own!
#
# In the cell below, define a function called sign which takes a numerical argument and returns -1 if it's negative, 1 if it's positive, and 0 if it's 0.

# %%
# Your code goes here. Define a function called 'sign'
def sign(x):
    if x < 0:
        return -1
    elif x > 0:
        return 1
    else:
        return 0

# Menggunakan fungsi sign dengan beberapa contoh
print(sign(-5))  # Output: -1
print(sign(10))  # Output: 1
print(sign(0))   # Output: 0
# Out:
# -1
# 1
# 0

# %% [markdown]
# 2. We've decided to add "logging" to our to_smash function from the previous exercise.

# %%
def to_smash(total_candies):
    """Mengembalikan jumlah permen yang tersisa yang harus dihancurkan setelah mendistribusikan
    jumlah permen yang diberikan secara merata kepada 3 teman.

    >>> to_smash(91)
    1
    """
    print("Membagi", total_candies, "permen")  # Mencetak pesan yang memberi tahu kita sedang membagi permen
    return total_candies % 3  # Mengembalikan sisa permen setelah pembagian dengan 3

to_smash(91)  # Memanggil fungsi to_smash dengan argumen 91
# Out:
# Membagi 91 permen
# 1

# %% [markdown]
# Modify the definition in the cell below to correct the grammar of our print statement. (If there's only one candy, we should use the singular "candy" instead of the plural "candies")

# %%
def to_smash(total_candies):
    """Mengembalikan jumlah permen yang tersisa yang harus dihancurkan setelah mendistribusikan
    jumlah permen yang diberikan secara merata kepada 3 teman.

    >>> to_smash(91)
    1
    """
    print("Membagi", total_candies, "permen")  # Mencetak pesan yang memberi tahu kita sedang membagi permen
    return total_candies % 3  # Mengembalikan sisa permen setelah pembagian dengan 3

to_smash(91)  # Memanggil fungsi to_smash dengan argumen 91
to_smash(1)   # Memanggil fungsi to_smash dengan argumen 1
# Out:
# Membagi 91 permen
# Membagi 1 permen
# 1

# %% [markdown]
# 3. 🌶️
#
# In the tutorial, we talked about deciding whether we're prepared for the weather. I said that I'm safe from today's weather if...
#
# I have an umbrella...
# or if the rain isn't too heavy and I have a hood...
# otherwise, I'm still fine unless it's raining and it's a workday
# The function below uses our first attempt at turning this logic into a Python expression. I claimed that there was a bug in that code. Can you find it?
#
# To prove that prepared_for_weather is buggy, come up with a set of inputs where either:
#
# the function returns False (but should have returned True), or
# the function returned True (but should have returned False).
# To get credit for completing this question, your code should return a Correct result.

# %%
# Ini adalah definisi dari fungsi prepared_for_weather
def prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday):
    # Perbaikan logika dengan menggunakan tanda kurung
    return have_umbrella or (rain_level < 5 and have_hood) or (not rain_level > 0 and is_workday)

# Inisialisasi variabel-variabel yang akan digunakan sebagai argumen untuk fungsi
have_umbrella = False
rain_level = 0.0
have_hood = False
is_workday = True

# Memanggil fungsi prepared_for_weather dengan argumen yang telah diinisialisasi
actual = prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday)

# Mencetak hasil yang dikembalikan oleh fungsi
print(actual)
# Out:
# True

# %% [markdown]
# 4. The function is_negative below is implemented correctly - it returns True if the given number is negative and False otherwise.
#
# However, it's more verbose than it needs to be. We can actually reduce the number of lines of code in this function by 75% while keeping the same behaviour.
#
# See if you can come up with an equivalent body that uses just one line of code, and put it in the function concise_is_negative. (HINT: you don't even need Python's ternary syntax)

# %%
# Ini adalah definisi dari fungsi is_negative
def is_negative(number):
    if number < 0:
        return True
    else:
        return False

# Ini adalah definisi dari fungsi concise_is_negative yang lebih ringkas
def concise_is_negative(number):
    return number < 0  # Mengembalikan hasil evaluasi ekspresi pembanding

# Memanggil fungsi is_negative dengan argumen -5
result1 = is_negative(-5)

# Memanggil fungsi concise_is_negative dengan argumen -5
result2 = concise_is_negative(-5)

# Mencetak hasil dari kedua fungsi
print("Result from is_negative:", result1)
print("Result from concise_is_negative:", result2)
# Out:
# Result from is_negative: True
# Result from concise_is_negative: True

# %% [markdown]
# 5a. The boolean variables ketchup, mustard and onion represent whether a customer wants a particular topping on their hot dog. We want to implement a number of boolean functions that correspond to some yes-or-no questions about the customer's order. For example:

# %%
def onionless(ketchup, mustard, onion):
    """Return whether the customer doesn't want onions.
    """
    return not onion

# %%
# Ini adalah definisi dari fungsi wants_all_toppings
def wants_all_toppings(ketchup, mustard, onion):
    """Return whether the customer wants "the works" (all 3 toppings)
    """
    return ketchup and mustard and onion  # Mengembalikan True jika semua topping diinginkan

# Memanggil fungsi wants_all_toppings dengan berbagai kombinasi topping
result1 = wants_all_toppings(True, True, True)
result2 = wants_all_toppings(True, True, False)
result3 = wants_all_toppings(True, False, True)
result4 = wants_all_toppings(False, True, True)

# Mencetak hasil dari fungsi
print("Result 1 (All toppings wanted):", result1)
print("Result 2 (Mustard and ketchup wanted, onion not wanted):", result2)
print("Result 3 (Ketchup and onion wanted, mustard not wanted):", result3)
print("Result 4 (Mustard and onion wanted, ketchup not wanted):", result4)
# Out:
# Result 1 (All toppings wanted): True
# Result 2 (Mustard and ketchup wanted, onion not wanted): False
# Result 3 (Ketchup and onion wanted, mustard not wanted): False
# Result 4 (Mustard and onion wanted, ketchup not wanted): False

# %% [markdown]
# 5b. For the next function, fill in the body to match the English description in the docstring.

# %%
# Ini adalah definisi dari fungsi wants_plain_hotdog
def wants_plain_hotdog(ketchup, mustard, onion):
    """Return whether the customer wants a plain hot dog with no toppings.
    """
    return not (ketchup or mustard or onion)  # Mengembalikan True jika tidak ada topping yang diinginkan

# Memanggil fungsi wants_plain_hotdog dengan berbagai kombinasi topping
result1 = wants_plain_hotdog(False, False, False)
result2 = wants_plain_hotdog(True, False, False)
result3 = wants_plain_hotdog(False, True, False)
result4 = wants_plain_hotdog(False, False, True)
result5 = wants_plain_hotdog(True, True, True)

# Mencetak hasil dari fungsi
print("Result 1 (No toppings wanted):", result1)
print("Result 2 (Ketchup wanted, no other toppings):", result2)
print("Result 3 (Mustard wanted, no other toppings):", result3)
print("Result 4 (Onion wanted, no other toppings):", result4)
print("Result 5 (All toppings wanted):", result5)
# Out:
# Result 1 (No toppings wanted): True
# Result 2 (Ketchup wanted, no other toppings): False
# Result 3 (Mustard wanted, no other toppings): False
# Result 4 (Onion wanted, no other toppings): False
# Result 5 (All toppings wanted): False

# %% [markdown]
# 5c. You know what to do: for the next function, fill in the body to match the English description in the docstring.

# %%
# Ini adalah definisi dari fungsi exactly_one_sauce
def exactly_one_sauce(ketchup, mustard, onion):
    """Return whether the customer wants either ketchup or mustard, but not both.
    (You may be familiar with this operation under the name "exclusive or")
    """
    return (ketchup and not mustard) or (mustard and not ketchup)

# Memanggil fungsi exactly_one_sauce dengan berbagai kombinasi topping
result1 = exactly_one_sauce(False, False, False)
result2 = exactly_one_sauce(True, False, False)
result3 = exactly_one_sauce(False, True, False)
result4 = exactly_one_sauce(False, False, True)
result5 = exactly_one_sauce(True, True, False)
result6 = exactly_one_sauce(True, False, True)
result7 = exactly_one_sauce(False, True, True)
result8 = exactly_one_sauce(True, True, True)

# Mencetak hasil dari fungsi
print("Result 1 (Neither ketchup nor mustard wanted):", result1)
print("Result 2 (Ketchup wanted, mustard not wanted):", result2)
print("Result 3 (Mustard wanted, ketchup not wanted):", result3)
print("Result 4 (Onion wanted, no sauce wanted):", result4)
print("Result 5 (Both ketchup and mustard wanted):", result5)
print("Result 6 (Ketchup and onion wanted, mustard not wanted):", result6)
print("Result 7 (Mustard and onion wanted, ketchup not wanted):", result7)
print("Result 8 (All toppings wanted):", result8)
# Out:
# Result 1 (Neither ketchup nor mustard wanted): False
# Result 2 (Ketchup wanted, mustard not wanted): True
# Result 3 (Mustard wanted, ketchup not wanted): True
# Result 4 (Onion wanted, no sauce wanted): False
# Result 5 (Both ketchup and mustard wanted): False
# Result 6 (Ketchup and onion wanted, mustard not wanted): True
# Result 7 (Mustard and onion wanted, ketchup not wanted): True
# Result 8 (All toppings wanted): False

# %% [markdown]
# 6. 🌶️
#
#
# We’ve seen that calling bool() on an integer returns False if it’s equal to 0 and True otherwise. What happens if we call int() on a bool? Try it out in the notebook cell below.
#
# Can you take advantage of this to write a succinct function that corresponds to the English sentence "does the customer want exactly one topping?"?

# %%
# Ini adalah definisi dari fungsi exactly_one_topping
def exactly_one_topping(ketchup, mustard, onion):
    """Return whether the customer wants exactly one of the three available toppings
    on their hot dog.
    """
    # Menghitung jumlah topping yang diinginkan
    num_toppings = ketchup + mustard + onion

    # Memeriksa apakah jumlah topping sama dengan satu
    return num_toppings == 1

# Memanggil fungsi exactly_one_topping dengan berbagai kombinasi topping
result1 = exactly_one_topping(False, False, False)
result2 = exactly_one_topping(True, False, False)
result3 = exactly_one_topping(False, True, False)
result4 = exactly_one_topping(False, False, True)
result5 = exactly_one_topping(True, True, False)
result6 = exactly_one_topping(True, False, True)
result7 = exactly_one_topping(False, True, True)
result8 = exactly_one_topping(True, True, True)

# Mencetak hasil dari fungsi
print("Result 1 (No topping wanted):", result1)
print("Result 2 (Ketchup wanted):", result2)
print("Result 3 (Mustard wanted):", result3)
print("Result 4 (Onion wanted):", result4)
print("Result 5 (Both ketchup and mustard wanted):", result5)
print("Result 6 (Ketchup and onion wanted):", result6)
print("Result 7 (Mustard and onion wanted):", result7)
print("Result 8 (All toppings wanted):", result8)
# Out:
# Result 1 (No topping wanted): False
# Result 2 (Ketchup wanted): True
# Result 3 (Mustard wanted): True
# Result 4 (Onion wanted): True
# Result 5 (Both ketchup and mustard wanted): False
# Result 6 (Ketchup and onion wanted): False
# Result 7 (Mustard and onion wanted): False
# Result 8 (All toppings wanted): False

# %% [markdown]
# 7. 🌶️ (Optional)
#
# In this problem we'll be working with a simplified version of blackjack (aka twenty-one). In this version there is one player (who you'll control) and a dealer. Play proceeds as follows:
#
# The player is dealt two face-up cards. The dealer is dealt one face-up card.
# The player may ask to be dealt another card ('hit') as many times as they wish. If the sum of their cards exceeds 21, they lose the round immediately.
# The dealer then deals additional cards to himself until either:
# the sum of the dealer's cards exceeds 21, in which case the player wins the round
# the sum of the dealer's cards is greater than or equal to 17. If the player's total is greater than the dealer's, the player wins. Otherwise, the dealer wins (even in case of a tie).
# When calculating the sum of cards, Jack, Queen, and King count for 10. Aces can count as 1 or 11 (when referring to a player's "total" above, we mean the largest total that can be made without exceeding 21. So e.g. A+8 = 19, A+8+8 = 17)
#
# For this problem, you'll write a function representing the player's decision-making strategy in this game. We've provided a very unintelligent implementation below:

# %%
def should_hit(dealer_total, player_total, player_low_aces, player_high_aces):
    """Return True if the player should hit (request another card) given the current game
    state, or False if the player should stay.
    When calculating a hand's total value, we count aces as "high" (with value 11) if doing so
    doesn't bring the total above 21, otherwise we count them as low (with value 1).
    For example, if the player's hand is {A, A, A, 7}, we will count it as 11 + 1 + 1 + 7,
    and therefore set player_total=20, player_low_aces=2, player_high_aces=1.
    """
    return False

# %% [markdown]
# This very conservative agent always sticks with the hand of two cards that they're dealt.
#
# We'll be simulating games between your player agent and our own dealer agent by calling your function.
#
# Try running the function below to see an example of a simulated game:

# %%
def simulate_one_game():
    # Simulasikan satu permainan dan kembalikan hasilnya
    total_dealer = random.randint(12, 21)  # Simulasikan total kartu dealer
    total_pemain = random.randint(12, 21)  # Simulasikan total kartu pemain

    # Tentukan keputusan pemain menggunakan fungsi should_hit
    hit = should_hit(total_dealer, total_pemain, 0, 0)  # Dengan asumsi tidak ada kartu as

    # Tentukan hasil permainan berdasarkan keputusan hit dan total kartu dealer
    if hit:
        total_pemain += random.randint(1, 10)  # Simulasikan mengambil kartu
        if total_pemain > 21:
            return 'kalah'
    else:
        while total_dealer < 17:
            total_dealer += random.randint(1, 10)  # Simulasikan dealer mengambil kartu
        if total_dealer > 21 or total_pemain > total_dealer:
            return 'menang'
        elif total_pemain == total_dealer:
            return 'seri'
        else:
            return 'kalah'

# Simulasikan satu permainan
print("Hasil Satu Permainan:", simulate_one_game())
# Out:
# Hasil Satu Permainan: menang

# %%
import random

def player_decision(player_hand, dealer_card):
    """
    Strategi pengambilan keputusan pemain.

    Args:
    player_hand (list): Daftar kartu di tangan pemain.
    dealer_card (int): Kartu wajah dealer.

    Returns:
    str: Keputusan pemain - 'hit' atau 'stand'.
    """
    total_pemain = calculate_total(player_hand)

    # Implementasikan logika pengambilan keputusan di sini
    # Contoh: Jika total pemain kurang dari 17, hit; jika tidak, stand
    if total_pemain < 17:
        return 'hit'
    else:
        return 'stand'

def calculate_total(hand):
    """
    Hitung nilai total dari sebuah tangan, dengan mempertimbangkan Aces.

    Args:
    hand (list): Daftar kartu dalam tangan.

    Returns:
    int: Nilai total dari tangan.
    """
    total = sum([nilai_kartu(kartu) for kartu in hand])
    num_ases = hand.count('A')  # Hitung jumlah Aces dalam tangan

    # Sesuaikan nilai total untuk Aces
    while num_ases > 0 and total > 21:
        total -= 10  # Anggap Ace sebagai 1 bukan 11
        num_ases -= 1

    return total

def nilai_kartu(kartu):
    """
    Dapatkan nilai numerik dari sebuah kartu.

    Args:
    kartu (str): Nilai kartu sebagai string.

    Returns:
    int: Nilai numerik dari kartu.
    """
    if kartu in ['K', 'Q', 'J']:
        return 10
    elif kartu == 'A':
        return 11
    else:
        return int(kartu)

# Contoh penggunaan:
player_hand = ['A', '8']  # Tangan pemain dengan Ace dan 8
dealer_card = '6'      # Kartu wajah dealer adalah 6

# Buat keputusan berdasarkan strategi pemain
keputusan = player_decision(player_hand, dealer_card)
print(f"Keputusan Pemain: {keputusan}")
# Out:
# Keputusan Pemain: stand

# %% [markdown]
# #  💻 Exercise: Lists 💻

# %% [markdown]
# 1. Complete the function below according to its docstring

# %%
# Daftar dengan lebih dari satu elemen
daftar_1 = [1, 2, 3, 4, 5]
hasil_1 = select_second(daftar_1)
print(f"Elemen kedua dari daftar pertama: {hasil_1}")

# Daftar dengan hanya satu elemen
daftar_2 = [42]
hasil_2 = select_second(daftar_2)
print(f"Elemen kedua dari daftar kedua: {hasil_2}")

# Daftar kosong
daftar_kosong = []
hasil_kosong = select_second(daftar_kosong)
print(f"Elemen kedua dari daftar kosong: {hasil_kosong}")
# Out:
# Elemen kedua dari daftar pertama: 2
# Elemen kedua dari daftar kedua: None
# Elemen kedua dari daftar kosong: None

# %% [markdown]
# 2. You are analyzing sports teams. Members of each team are stored in a list. The Coach is the first name in the list, the captain is the second name in the list, and other players are listed after that. These lists are stored in another list, which starts with the best team and proceeds through the list to the worst team last. Complete the function below to select the captain of the worst team.

# %%
def losing_team_captain(teams):
    """Diberikan daftar tim, di mana setiap tim adalah daftar nama, kembalikan pemain kedua (kapten)
    dari tim terakhir yang terdaftar.
    """
    if len(teams) == 0:
        return None  # Jika daftar tim kosong, kembalikan None
    else:
        last_team = teams[-1]  # Tim terakhir dalam daftar
        if len(last_team) >= 2:
            return last_team[1]  # Kapten adalah pemain kedua dalam tim terakhir
        else:
            return None  # Jika tim terakhir memiliki kurang dari 2 pemain, kembalikan None

# Contoh penggunaan:
teams = [['Tim A', 'Pemain 1', 'Pemain 2'], ['Tim B', 'Kapten B'], ['Tim C']]

# Panggil fungsi losing_team_captain
kapten = losing_team_captain(teams)

# Cetak hasil
if kapten is not None:
    print(f"Kapten dari tim terakhir: {kapten}")
else:
    print("Tidak ada tim atau tim terakhir tidak memiliki kapten")
# Out:
# Tidak ada tim atau tim terakhir tidak memiliki kapten

# %% [markdown]
# 3. The next iteration of Mario Kart will feature an extra-infuriating new item, the Purple Shell. When used, it warps the last place racer into first place and the first place racer into last place. Complete the function below to implement the Purple Shell's effect.

# %%
def purple_shell(racers):
    # Diberikan daftar para pembalap, ubah posisi pembalap pertama (di depan daftar) menjadi posisi terakhir dan sebaliknya.

    # Cek apakah ada setidaknya dua pembalap dalam daftar
    if len(racers) >= 2:
        # Tukar posisi pembalap pertama dengan terakhir menggunakan pertukaran nilai ganda
        racers[0], racers[-1] = racers[-1], racers[0]

# Penggunaan contoh:
pembalap = ["Mario", "Bowser", "Luigi"]
purple_shell(pembalap)
print("Hasil setelah menggunakan purple shell:", pembalap)
# Out:
# Hasil setelah menggunakan purple shell: ['Luigi', 'Bowser', 'Mario']

# %% [markdown]
# 4. What are the lengths of the following lists? Fill in the variable lengths with your predictions. (Try to make a prediction for each list without just calling len() on it.)

# %%
# Mendefinisikan variabel a, b, c, dan d
a = [1, 2, 3]
b = [1, [2, 3]]
c = []
d = [1, 2, 3][1:]

# Mengisi panjang masing-masing variabel ke dalam list 'lengths'
lengths = [len(a), len(b), len(c), len(d)]

# Cetak panjang masing-masing variabel
print(f"Panjang a: {lengths[0]}")
print(f"Panjang b: {lengths[1]}")
print(f"Panjang c: {lengths[2]}")
print(f"Panjang d: {lengths[3]}")
# Out:
# Panjang a: 3
# Panjang b: 2
# Panjang c: 0
# Panjang d: 2

# %% [markdown]
# 5. 🌶️
# We're using lists to record people who attended our party and what order they arrived in. For example, the following list represents a party with 7 guests, in which Adela showed up first and Ford was the last to arrive:
#
# party_attendees = ['Adela', 'Fleda', 'Owen', 'May', 'Mona', 'Gilbert', 'Ford']
# A guest is considered 'fashionably late' if they arrived after at least half of the party's guests. However, they must not be the very last guest (that's taking it too far). In the above example, Mona and Gilbert are the only guests who were fashionably late.
#
# Complete the function below which takes a list of party attendees as well as a person, and tells us whether that person is fashionably late.

# %%
def fashionably_late(arrivals, name):
    """Diberikan daftar kedatangan yang telah diurutkan dan sebuah nama, kembalikan apakah tamu dengan nama tersebut tiba terlambat dengan gaya.
    """
    # Hitung indeks tamu dengan nama yang diberikan dalam daftar kedatangan
    index = arrivals.index(name)

    # Periksa apakah tamu tersebut tiba setelah setengah jumlah tamu lainnya
    return index >= len(arrivals) / 2 and index != len(arrivals) - 1

# Contoh penggunaan:
arrivals = ["Alice", "Bob", "Charlie", "David", "Eve"]
name = "Charlie"

# Cek apakah tamu "Charlie" tiba terlambat dengan gaya
terlambat_dengan_gaya = fashionably_late(arrivals, name)

# Cetak hasil
if terlambat_dengan_gaya:
    print(f"{name} tiba terlambat dengan gaya.")
else:
    print(f"{name} tidak tiba terlambat dengan gaya.")
# Out:
# Charlie tidak tiba terlambat dengan gaya.

# %% [markdown]
# # 💻 Exercise: Loops and List Comprehensions 💻

# %% [markdown]
# 1. Have you ever felt debugging involved a bit of luck? The following program has a bug. Try to identify the bug and fix it.

# %%
def has_lucky_number(nums):
    """Return whether the given list of numbers is lucky. A lucky list contains
    at least one number divisible by 7.
    """
    for num in nums:
        # Periksa apakah angka dapat dibagi habis oleh 7
        if num % 7 == 0:
            return True
    # Mengembalikan False jika tidak ada angka yang memenuhi syarat
    return False

# %% [markdown]
# 2. Look at the Python expression below. What do you think we'll get when we run it? When you've made your prediction, uncomment the code and run the cell to see if you were right.
#
# ![1.png](data:image/png;base64,...)
#
# R and Python have some libraries (like numpy and pandas) compare each element of the list to 2 (i.e. do an 'element-wise' comparison) and give us a list of booleans like [False, False, True, True].
#
# Implement a function that reproduces this behaviour, returning a list of booleans corresponding to whether the corresponding element is greater than n.

# %%
def elementwise_greater_than(L, thresh):
    """Mengembalikan daftar dengan panjang yang sama seperti L, di mana nilai pada indeks i adalah
    True jika L[i] lebih besar dari thresh, dan False sebaliknya.
    """
    # Inisialisasi daftar hasil dengan daftar kosong
    result = []

    # Perulangan melalui setiap elemen dalam daftar L
    for num in L:
        # Periksa jika elemen lebih besar dari thresh
        if num > thresh:
            result.append(True)
        else:
            result.append(False)

    return result

# Contoh penggunaan:
L = [1, 2, 3, 4]
thresh = 2
hasil = elementwise_greater_than(L, thresh)
print(hasil)
# Out:
# [False, False, True, True]

# %% [markdown]
# 3. Complete the body of the function below according to its docstring.

# %%
def menu_is_boring(meals):
    """Diberikan daftar hidangan yang disajikan selama beberapa periode waktu, kembalikan True jika
    hidangan yang sama pernah disajikan dua hari berturut-turut, dan False sebaliknya.
    """
    # Periksa setiap pasangan hidangan berturut-turut dalam daftar
    for i in range(len(meals) - 1):
        if meals[i] == meals[i + 1]:
            return True  # Ada hidangan yang sama dua hari berturut-turut

    return False  # Tidak ada hidangan yang sama dua hari berturut-turut

# Contoh penggunaan:
meals = ["Spaghetti", "Spaghetti", "Pizza", "Burger", "Burger"]
hasil = menu_is_boring(meals)
print(hasil)
# Out:
# True

# %% [markdown]
# 4. 🌶️
#
# Next to the Blackjack table, the Python Challenge Casino has a slot machine. You can get a result from the slot machine by calling play_slot_machine(). The number it returns is your winnings in dollars. Usually it returns 0. But sometimes you'll get lucky and get a big payday. Try running it below:
#
# ![2.png](data:image/png;base64,...)
#
# By the way, did we mention that each play costs $1? Don't worry, we'll send you the bill later.
#
# On average, how much money can you expect to gain (or lose) every time you play the machine? The casino keeps it a secret, but you can estimate the average value of each pull using a technique called the Monte Carlo method. To estimate the average outcome, we simulate the scenario many times, and return the average result.
#
# Complete the following function to calculate the average value per play of the slot machine.

# %%
import random

def estimate_average_slot_payout(n_runs):
    """Menjalankan mesin slot sebanyak n_runs kali dan mengembalikan rata-rata keuntungan bersih per putaran.
    """
    total_profit = 0  # Inisialisasi total keuntungan bersih
    for _ in range(n_runs):
        # Simulasi satu putaran mesin slot
        payout = random.randint(0, 100)  # Simulasi pembayaran acak antara 0 hingga 100
        cost = 1  # Biaya satu putaran mesin slot
        net_profit = payout - cost  # Keuntungan bersih dari satu putaran
        total_profit += net_profit  # Tambahkan keuntungan bersih ke total

    # Hitung rata-rata keuntungan bersih per putaran
    average_profit_per_run = total_profit / n_runs
    return average_profit_per_run

# Contoh penggunaan:
n_runs = 1000  # Anda dapat mengubah jumlah putaran mesin slot sesuai keinginan
rata_rata_keuntungan = estimate_average_slot_payout(n_runs)
print(f"Rata-rata Keuntungan Bersih per Putaran: {rata_rata_keuntungan}")
# Out:
# Rata-rata Keuntungan Bersih per Putaran: 49.337

# %% [markdown]
# # 💻 Exercise: Strings and Dictionaries 💻

# %% [markdown]
# 0a.

# %%
a = ""
length = len(a)  # Menghitung panjang string a

# %% [markdown]
# 0b.

# %%
b = "it's ok"
length = len(b)  # Menghitung panjang string b

# %% [markdown]
# 0c.

# %%
c = 'it\'s ok'
length = len(c)  # Menghitung panjang string c

# %% [markdown]
# 0d.

# %%
d = """hey"""
length = len(d)  # Menghitung panjang string d

# %% [markdown]
# 0e.

# %%
e = '\n'
length = len(e)  # Menghitung panjang string e

# %% [markdown]
# 1. There is a saying that "Data scientists spend 80% of their time cleaning data, and 20% of their time complaining about cleaning data." Let's see if you can write a function to help clean US zip code data. Given a string, it should return whether or not that string represents a valid zip code. For our purposes, a valid zip code is any string consisting of exactly 5 digits.
#
# HINT: str has a method that will be useful here. Use help(str) to review a list of string methods.

# %%
def is_valid_zip(zip_code):
    """Mengembalikan apakah string input adalah kode pos yang valid (5 digit).
    """
    # Memeriksa panjang string harus 5 karakter
    if len(zip_code) == 5:
        # Memeriksa apakah string hanya terdiri dari digit
        if zip_code.isdigit():
            return True
    return False

# Contoh penggunaan:
zip_code = "12345"  # Ganti dengan kode pos yang ingin Anda periksa
valid = is_valid_zip(zip_code)
print(valid)
# Out:
# True

# %% [markdown]
# 2. A researcher has gathered thousands of news articles. But she wants to focus her attention on articles including a specific word. Complete the function below to help her filter her list of articles.
#
# Your function should meet the following criteria:
#
# Do not include documents where the keyword string shows up only as a part of a larger word. For example, if she were looking for the keyword “closed”, you would not include the string “enclosed.”
# She does not want you to distinguish upper case from lower case letters. So the phrase “Closed the case.” would be included when the keyword is “closed”
# Do not let periods or commas affect what is matched. “It is closed.” would be included when the keyword is “closed”. But you can assume there are no other types of punctuation.

# %%
def word_search(doc_list, keyword):
    # List untuk menyimpan indeks dokumen yang sesuai
    indeks = []
    # Melakukan iterasi melalui indeks (i) dan elemen (doc) dari dokumen
    for i, doc in enumerate(doc_list):
        # Memisahkan string doc menjadi daftar kata (berdasarkan spasi)
        tokens = doc.split()
        # Membuat daftar tertransformasi di mana setiap kata 'dinormalisasi' untuk memfasilitasi pencocokan.
        # Titik dan koma dihapus dari akhir setiap kata, dan kata tersebut diubah menjadi huruf kecil.
        normalized = [token.rstrip('.,').lower() for token in tokens]
        # Apakah ada yang cocok? Jika ya, perbarui daftar indeks yang cocok.
        if keyword.lower() in normalized:
            indeks.append(i)
    return indeks

# Contoh penggunaan:
doc_list = ["Ini adalah dokumen pertama.", "Ini adalah dokumen kedua.", "Ini adalah dokumen ketiga."]
keyword = "kedua"
hasil_pencarian = word_search(doc_list, keyword)
print(hasil_pencarian)
# Out:
# [1]

# %% [markdown]
# 3. Now the researcher wants to supply multiple keywords to search for. Complete the function below to help her.
#
# (You're encouraged to use the word_search function you just wrote when implementing this function. Reusing code in this way makes your programs more robust and readable - and it saves typing!)

# %%
# Fungsi untuk mencari kata kunci dalam satu dokumen
def word_search(doc_list, keyword):
    # List untuk menyimpan indeks dokumen yang sesuai
    indices = []

    # Melakukan iterasi melalui indeks (i) dan elemen (doc) dari dokumen
    for i, doc in enumerate(doc_list):
        # Memisahkan string doc menjadi daftar kata (berdasarkan spasi)
        tokens = doc.split()

        # Membuat daftar tertransformasi di mana setiap kata 'dinormalisasi' untuk memfasilitasi pencocokan.
        # Titik dan koma dihapus dari akhir setiap kata, dan kata tersebut diubah menjadi huruf kecil.
        normalized = [token.rstrip('.,').lower() for token in tokens]

        # Apakah ada yang cocok? Jika ya, perbarui daftar indeks yang cocok.
        if keyword.lower() in normalized:
            indices.append(i)

    # Mengembalikan daftar indeks yang sesuai
    return indices

# Fungsi untuk mencari beberapa kata kunci dalam beberapa dokumen
def multi_word_search(doc_list, keywords):
    # Kamus untuk menyimpan hasil pencarian kata kunci
    keyword_to_indices = {}

    # Melakukan pencarian untuk setiap kata kunci dalam daftar kata kunci
    for keyword in keywords:
        # Menggunakan fungsi word_search untuk mencari kata kunci dalam dokumen
        hasil_pencarian = word_search(doc_list, keyword)

        # Menyimpan hasil pencarian dalam kamus dengan kata kunci sebagai kunci (key) kamusnya
        keyword_to_indices[keyword] = hasil_pencarian

    # Mengembalikan kamus hasil pencarian
    return keyword_to_indices

# Contoh penggunaan:
doc_list = ["Ini adalah dokumen pertama.", "Ini adalah dokumen kedua.", "Ini adalah dokumen ketiga."]
keywords = ["kedua", "pertama"]
hasil_pencarian = multi_word_search(doc_list, keywords)
print(hasil_pencarian)
# Out:
# {'kedua': [1], 'pertama': [0]}

# %% [markdown]
# ## 💻 Exercise: Working with External Libraries 💻

# %% [markdown]
# 1. After completing the exercises on lists and tuples, Jimmy noticed that, according to his estimate_average_slot_payout function, the slot machines at the Learn Python Casino are actually rigged against the house, and are profitable to play in the long run.
#
# Starting with $200 in his pocket, Jimmy has played the slots 500 times, recording his new balance in a list after each spin. He used Python's matplotlib library to make a graph of his balance over time:
#
# ![3.png](data:image/png;base64,...)
#
# As you can see, he's hit a bit of bad luck recently. He wants to tweet this along with some choice emojis, but, as it looks right now, his followers will probably find it confusing. He's asked if you can help him make the following changes:
#
# Add the title "Results of 500 slot machine pulls"
# Make the y-axis start at 0.
# Add the label "Balance" to the y-axis
# After calling type(graph) you see that Jimmy's graph is of type matplotlib.axes._subplots.AxesSubplot. Hm, that's a new one. By calling dir(graph), you find three methods that seem like they'll be useful: .set_title(), .set_ylim(), and .set_ylabel().
#
# Use these methods to complete the function prettify_graph according to Jimmy's requests. We've already checked off the first request for you (setting a title).
#
# (Remember: if you don't know what these methods do, use the help() function!)
#
# ![4.png](data:image/png;base64,...)
#
# Bonus: Can you format the numbers on the y-axis so they look like dollar amounts? e.g. $200 instead of just 200.
#
# (We're not going to tell you what method(s) to use here. You'll need to go digging yourself with dir(graph) and/or help(graph).)

# %%
def prettify_graph(graph):
    graph.set_title("Results of 500 slot machine pulls")
    # Make the y-axis begin at 0
    graph.set_ylim(bottom=0)
    # Label the y-axis
    graph.set_ylabel("Balance")
    # Bonus: format the numbers on the y-axis as dollar amounts
    # An array of the values displayed on the y-axis (150, 175, 200, etc.)
    ticks = graph.get_yticks()
    # Format those values into strings beginning with dollar sign
    new_labels = ['${}'.format(int(amt)) for amt in ticks]
    # Set the new labels
    graph.set_yticklabels(new_labels)

# %% [markdown]
# 2. 🌶️🌶️
#
# This is a very challenging problem. Don't forget that you can receive a hint!
#
# Luigi is trying to perform an analysis to determine the best items for winning races on the Mario Kart circuit. He has some data in the form of lists of dictionaries that look like...
#
# [
#     {'name': 'Peach', 'items': ['green shell', 'banana', 'green shell',], 'finish': 3},
#     {'name': 'Bowser', 'items': ['green shell',], 'finish': 1},
#     # Sometimes the racer's name wasn't recorded
#     {'name': None, 'items': ['mushroom',], 'finish': 2},
#     {'name': 'Toad', 'items': ['green shell', 'mushroom'], 'finish': 1},
# ]
# 'items' is a list of all the power-up items the racer picked up in that race, and 'finish' was their placement in the race (1 for first place, 3 for third, etc.).
#
# He wrote the function below to take a list like this and return a dictionary mapping each item to how many times it was picked up by first-place finishers.

# %%
def best_items(racers):
    """Given a list of racer dictionaries, return a dictionary mapping items to the number
    of times those items were picked up by racers who finished in first place.
    """
    winner_item_counts = {}
    for i in range(len(racers)):
        # The i'th racer dictionary
        racer = racers[i]
        # We're only interested in racers who finished in first
        if racer['finish'] == 1:
            for i in racer['items']:
                # Add one to the count for this item (adding it to the dict if necessary)
                if i not in winner_item_counts:
                    winner_item_counts[i] = 0
                winner_item_counts[i] += 1

        # Data quality issues :/ Print a warning about racers with no name set. We'll take care of it later.
        if racer['name'] is None:
            print("WARNING: Encountered racer with unknown name on iteration {}/{} (racer = {})".format(
                i+1, len(racers), racer['name'])
                 )
    return winner_item_counts

# %% [markdown]
# He tried it on a small example list above and it seemed to work correctly:

# %%
sample = [
    {'name': 'Peach', 'items': ['green shell', 'banana', 'green shell',], 'finish': 3},
    {'name': 'Bowser', 'items': ['green shell',], 'finish': 1},
    {'name': None, 'items': ['mushroom',], 'finish': 2},
    {'name': 'Toad', 'items': ['green shell', 'mushroom'], 'finish': 1},
]
best_items(sample)
# Out:
# WARNING: Encountered racer with unknown name on iteration 3/4 (racer = None)
# {'green shell': 2, 'mushroom': 1}

# %% [markdown]
# However, when he tried running it on his full dataset, the program crashed with a TypeError.
#
# Can you guess why? Try running the code cell below to see the error message Luigi is getting. Once you've identified the bug, fix it in the cell below (so that it runs without any errors).
#
# Hint: Luigi's bug is similar to one we encountered in the tutorial when we talked about star imports.

# %% [markdown]
# ```
# # # Import dataset balapan penuh dari Luigi
# from learntools.python.luigi_analysis import full_dataset
#
# # Fungsi untuk menghitung item terbaik dari pemenang balapan
# def best_items(racers):
#     # Inisialisasi kamus (dictionary) untuk menghitung item pemenang
#     winner_item_counts = {}
#
#     # Melakukan iterasi melalui indeks (i) dan elemen (racer) dalam daftar pembalap
#     for i in range(len(racers)):
#         # Pembalap dalam indeks ke-i
#         racer = racers[i]
#
#         # Kita hanya tertarik pada pembalap yang finish di posisi pertama (1)
#         if racer['finish'] == 1:
#             for item in racer['items']:
#                 # Menambahkan satu ke hitungan untuk item ini (menambahkannya ke kamus jika diperlukan)
#                 if item not in winner_item_counts:
#                     winner_item_counts[item] = 0
#                 winner_item_counts[item] += 1
#
#         # Masalah kualitas data :/ Mencetak peringatan tentang pembalap yang tidak memiliki nama. Ini akan diatasi nanti.
#         if racer['name'] is None:
#             print("PERINGATAN: Menemui pembalap dengan nama yang tidak diketahui pada iterasi {}/{} (racer = {})".format(
#                 i+1, len(racers), racer['name'])
#                  )
#     return winner_item_counts
#
# # Mencoba menganalisis dataset balapan penuh yang diimpor
# best_items(full_dataset)
# ```
#
# ![Screenshot 2023-09-29 101622.png](data:image/png;base64,...)

# %% [markdown]
# 3. 🌶️
#
# Suppose we wanted to create a new type to represent hands in blackjack. One thing we might want to do with this type is overload the comparison operators like >n ad <= so that we could use them to check whether one hand beats another. e.g. it'd be cool if we could do this:
#
# >>> hand1 = BlackjackHand(['K', 'A'])
# >>> hand2 = BlackjackHand(['7', '10', 'A'])
# >>> hand1 > hand2
# True
# Well, we're not going to do all that in this question (defining custom classes is a bit beyond the scope of these lessons), but the code we're asking you to write in the function below is very similar to what we'd have to write if we were defining our own BlackjackHand class. (We'd put it in the __gt__ magic method to define our custom behaviour for >.)
#
# Fill in the body of the blackjack_hand_greater_than function according to the docstring.

# %%
def blackjack_hand_greater_than(hand_1, hand_2):
    # Fungsi ini menghitung total nilai tangan berdasarkan aturan blackjack.
    def calculate_hand_total(hand):
        total = 0  # Total nilai awal tangan.
        num_aces = 0  # Jumlah kartu As dalam tangan.

        for card in hand:
            if card.isdigit():
                total += int(card)  # Kartu bernilai angka, tambahkan nilainya.
            elif card in ['K', 'Q', 'J']:
                total += 10  # Kartu wajah (Raja, Ratna, Jack) bernilai 10.
            elif card == 'A':
                num_aces += 1  # Hitung kartu As.
                total += 11  # Asumsikan nilai kartu As sebagai 11.

        # Periksa apakah ada kartu As yang harus dihitung sebagai 1 untuk menghindari melebihi 21.
        while num_aces > 0 and total > 21:
            total -= 10  # Ubah nilai kartu As dari 11 menjadi 1.
            num_aces -= 1

        return total  # Kembalikan total nilai tangan.

    total_1 = calculate_hand_total(hand_1)  # Hitung total nilai tangan pertama.
    total_2 = calculate_hand_total(hand_2)  # Hitung total nilai tangan kedua.

    # Tentukan hasil permainan berdasarkan aturan blackjack.
    return total_1 <= 21 and (total_1 > total_2 or total_2 > 21)

# %% [markdown]
# ![Screenshot 2023-09-29 102138.png](data:image/png;base64,...)

# %% [markdown]
# # Sertifikat Penyelesaian Course Python di Kaggle
#
# ![Daffa Asyqar Ahmad Khalisheka - Python.png](data:image/png;base64,...)
